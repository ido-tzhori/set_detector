# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    try:
        frame = video_display_sets(frame)
    except:
        pass
    time.sleep(2)
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
cv2.destroyWindow('frame')
# Out:
# oval 2 red striped
# diamonds 1 purple empty
# squiggle 1 purple empty
# diamonds 3 green empty
# oval 1 green empty
# squiggle 3 red empty
# oval 1 green empty
# diamonds 1 purple empty
# diamonds 3 green empty
# squiggle 1 purple empty
# oval 2 red striped
# squiggle 3 red empty
# oval 3 red empty
# squiggle 1 purple empty
# oval 1 green striped
# diamonds 1 purple empty
# oval 1 red empty
# squiggle 3 red empty
# squiggle 1 purple empty
# diamonds 3 green empty
# diamonds 1 purple empty
# oval 1 green empty
# squiggle 1 red full
# squiggle 1 purple empty
# oval 3 red striped
# oval 1 green striped
# squiggle 1 purple empty
# squiggle 3 red empty
# squiggle 1 green empty
# diamonds 1 purple empty oval 3 red striped
# squiggle 1 purple empty
#
# diamonds 3 green empty
# oval 1 green striped
# squiggle 3 red empty
# oval 1 green striped
# diamonds 3 green empty
# oval 3 red striped
# diamonds 1 purple empty
# squiggle 1 purple empty
# squiggle 3 red empty
# squiggle 1 purple empty
# oval 1 red empty
# oval 3 red empty
# diamonds 3 green empty
# oval 1 red empty
# diamonds 1 purple empty
# oval 1 green empty
# oval 2 red striped
# squiggle 3 red empty
# squiggle 1 purple empty
# diamonds 1 purple empty
# oval 3 red striped
# oval 1 green empty
# diamonds 2 green striped
# squiggle 3 red striped
# diamonds 1 purple empty
# oval 1 green empty
# oval 1 red empty
# squiggle 1 purple empty
# oval 2 red striped
# oval 3 red empty
# diamonds 3 green empty
# squiggle 3 red empty
# oval 1 red empty
# oval 3 red striped
# oval 1 green empty
# squiggle 1 purple empty
# oval 2 red empty
# diamonds 3 green empty
# oval 1 red empty
# diamonds 1 purple empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 green empty
# squiggle 1 purple empty
# oval 3 red striped
# oval 2 red empty
# oval 1 red empty
# diamonds 1 purple empty
# diamonds 3 green empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 red empty
# diamonds 3 green empty
# squiggle 1 purple empty
# oval 2 red empty
# diamonds 1 purple empty
# oval 1 green empty
# oval 1 red empty
# squiggle 3 red empty
# diamonds 1 purple empty
# oval 2 red empty
# diamonds 3 green empty
# oval 1 green empty
# oval 1 red empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 green empty
# diamonds 1 purple empty
# squiggle 1 purple empty
# oval 1 red empty
# oval 2 red empty
# oval 1 red empty
# diamonds 3 green empty
# squiggle 3 red empty
# oval 1 red empty
# diamonds 3 green empty
# oval 2 red empty
# oval 1 green empty
# squiggle 3 red empty
# oval 1 red empty
# oval 1 red empty
# diamonds 3 green empty
# oval 2 red empty
# oval 1 green empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 green empty
# oval 1 red empty
# oval 2 red empty
# diamonds 3 green empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 red striped
# oval 1 green empty
# oval 2 red empty
# oval 1 red empty
# diamonds 3 green empty
# squiggle 3 red empty
# diamonds 1 purple empty squiggle 1 purple empty
#
# oval 3 red empty
# oval 1 green empty
# squiggle 3 red empty
# diamonds 3 green empty
# squiggle 1 purple empty
# diamonds 1 purple empty
# diamonds 3 green empty
# oval 1 green empty
# oval 3 red empty
# squiggle 3 red empty
# oval 3 red empty
# oval 1 red empty
# squiggle 1 purple empty
# oval 1 green empty
# oval 2 red empty
# diamonds 1 purple empty
# oval 1 red empty
# diamonds 3 green empty
# squiggle 3 red empty
# diamonds 1 purple empty oval 1 green empty
#
# oval 3 red empty
# oval 2 red empty
# oval 1 red empty
# diamonds 3 green empty
# squiggle 1 purple empty
# oval 1 red empty
# squiggle 3 red empty
# squiggle 1 purple empty
# oval 3 red empty
# diamonds 1 purple empty
# oval 2 red empty
# oval 1 green empty
# oval 1 red striped
# diamonds 3 green empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 green empty
# diamonds 1 purple empty
# squiggle 1 purple empty
# oval 1 red empty
# oval 3 red empty
# diamonds 3 green empty
# oval 2 red empty
# oval 1 red empty
# squiggle 3 red empty
# oval 3 red empty
# diamonds 1 purple empty
# oval 1 green empty
# squiggle 1 purple empty
# oval 1 red empty
# oval 2 red empty
# diamonds 3 green empty
# oval 1 red empty
# squiggle 3 red empty
# oval 3 red empty
# oval 1 green empty
# squiggle 1 purple empty
# diamonds 3 green empty
# diamonds 1 purple empty
# oval 2 red empty
# oval 1 red empty
# oval 1 red empty
# squiggle 3 red empty
# oval 1 red striped
# diamonds 3 green empty
# oval 1 green empty
# squiggle 1 purple empty
# oval 3 red striped
# diamonds 1 purple empty
# oval 2 red striped
# oval 1 red empty
# squiggle 3 red empty
# oval 3 red empty diamonds 1 purple empty
#
# oval 1 green empty
# oval 1 red empty
# squiggle 1 purple empty
# diamonds 3 green empty
# oval 2 red empty
# oval 1 red empty
# squiggle 3 red empty
# oval 2 red striped
# squiggle 1 purple empty
# diamonds 3 green empty
# oval 3 red striped
# oval 1 red striped
# diamonds 1 purple empty
# oval 1 green striped
# oval 1 red empty
# squiggle 3 red empty
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3w/9k57jny569vcndjv5ty099p80000gn/T/ipykernel_20479/487709395.py in <module>
#       3 while True:
#       4     ret, frame = cap.read()
# ----> 5     frame = video_display_sets(frame)
#       6     time.sleep(2)
#       7     cv2.imshow('frame', frame)
#
# /var/folders/3w/9k57jny569vcndjv5ty099p80000gn/T/ipykernel_20479/968029849.py in video_display_sets(frame)
#     319         cards = executor.map(create_card, [frame] * len(cntrs), cntrs, corner_points, bounding_rects)
#     320
# --> 321     sets = return_all_sets(cards)
#     322 #     print(sets)
#     323     tup_sets = multiple(sets)
#
# /var/folders/3w/9k57jny569vcndjv5ty099p80000gn/T/ipykernel_20479/968029849.py in return_all_sets(cards)
#     233
#     234 def return_all_sets(cards):
# --> 235     combos = list(combinations(cards, 3))
#     236     sets = []
#     237     for combo in combos:
#
# /opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result_iterator()
#     607                     # Careful not to keep a reference to the popped future
#     608                     if timeout is None:
# --> 609                         yield fs.pop().result()
#     610                     else:
#     611                         yield fs.pop().result(end_time - time.monotonic())
#
# /opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     437                     raise CancelledError()
#     438                 elif self._state == FINISHED:
# --> 439                     return self.__get_result()
#     440
#     441                 self._condition.wait(timeout)
#
# /opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     389         if self._exception:
#     390             try:
# --> 391                 raise self._exception
#     392             finally:
#     393                 # Break a reference cycle with the exception in self._exception
#
# /opt/anaconda3/lib/python3.9/concurrent/futures/thread.py in run(self)
#      56
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#
# /var/folders/3w/9k57jny569vcndjv5ty099p80000gn/T/ipykernel_20479/968029849.py in create_card(img, cntr, corner_point, bounding_rect)
#     271     br = (x+w, y+h)
#     272     warped_image = birds_eye_view(img, corner_point, bounding_rect[2], bounding_rect[3])
# --> 273     shape,count,color,shade = label_card(warped_image)
#     274     s = " ".join([shape,str(count),color,shade]) + ' '
#     275     print(s)
#
# /var/folders/3w/9k57jny569vcndjv5ty099p80000gn/T/ipykernel_20479/968029849.py in label_card(warped_image)
#     209
#     210 def label_card(warped_image):
# --> 211     correct_contours = cards_contours(warped_image)
#     212     shape, count, first_contour = return_shape_count(warped_image, correct_contours)
#     213     color, shade = return_color_shade(warped_image, first_contour, shape)
#
# /var/folders/3w/9k57jny569vcndjv5ty099p80000gn/T/ipykernel_20479/968029849.py in cards_contours(img)
#     118     ctrs, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     119     areas = [cv2.contourArea(c) for c in ctrs]
# --> 120     max_area = np.max(areas)
#     121     correct_ctrs = []
#     122     for c in ctrs:
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2752     5
#    2753     """
# -> 2754     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2755                           keepdims=keepdims, initial=initial, where=where)
#    2756
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import cv2
import numpy as np
import sklearn.cluster
from collections import Counter
from itertools import combinations
import random
import concurrent.futures
import time

font = cv2.FONT_HERSHEY_COMPLEX

class Card:
    def __init__(self, tl_br, color, shape, count, shade):
        self.tl_br = tl_br
        self.color = color
        self.shape = shape
        self.count = count
        self.shade = shade
        
    def __str__(self):
        return f"{self.count} {self.color} {self.shape} {self.shade}"
    
    
    def __hash__(self):
        return hash((self.tl_br, self.color, self.shape, self.count, self.shade))

    def __eq__(self, other):
        if not isinstance(other, Card):
            return False
        return self.shape == other.shape and self.shade == other.shade and self.count == other.count and self.color == other.color and self.tl_br == other.tl_br
    
def resize(img, scale):
    scale_percent = scale  # percent of original size
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dim = (width, height)
    img = cv2.resize(img, dim, interpolation=cv2.INTER_AREA)
    return img


def pre_process(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (9, 9), 0)
#     t_lower = 50  # Lower Threshold
#     t_upper = 150  # Upper threshold
#     edge = cv2.Canny(blur, t_lower, t_upper)

    _, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_OTSU)
    ctrs, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    return ctrs

def relevant_contour(cnt, max_area):
    if max_area * 0.7 < cv2.contourArea(cnt) < max_area * 1.3:
        approx = cv2.approxPolyDP(cnt, 0.009 * cv2.arcLength(cnt, True), True)
        pts = np.float32(approx)
        x, y, w, h = cv2.boundingRect(cnt)
        return cnt, pts, [x,y,w,h]
    

def relevant_contours(contours):
    max_areas = [np.max([cv2.contourArea(c) for c in contours])] * len(contours)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        args_list = list(zip(contours, max_areas))
        futures = [executor.submit(relevant_contour, *args) for args in args_list]

        results = [future.result() for future in futures]
    
    cntrs = [result[0] for result in results if result is not None]
    corner_points = [result[1] for result in results if result is not None]
    bounding_rects = [result[2] for result in results if result is not None]
#     print(len(cntrs), len(corner_points), len(bounding_rects))

    return cntrs, corner_points, bounding_rects



def birds_eye_view(img, corner_points, w, h):
    temp_rect = np.zeros((4, 2), dtype="float32")

    s = np.sum(corner_points, axis=2)

    tl = corner_points[np.argmin(s)]
    br = corner_points[np.argmax(s)]

    diff = np.diff(corner_points, axis=-1)
    tr = corner_points[np.argmin(diff)]
    bl = corner_points[np.argmax(diff)]

    if w <= 0.8 * h:  # If card is vertically oriented
        tl_tr_br_bl = np.array([tl, tr, br, bl])

    if w >= 1.2 * h:  # If card is horizontally oriented
        tl_tr_br_bl = np.array([bl, tl, tr, br])

    else:
        tl_tr_br_bl = np.array([tl, tr, br, bl])

    max_width = 200
    max_height = 300

    dst = np.array([[0, 0], [max_width - 1, 0], [max_width - 1, max_height - 1], [0, max_height - 1]], np.float32)
    M = cv2.getPerspectiveTransform(tl_tr_br_bl, dst)
    warped_image = cv2.warpPerspective(img, M, (max_width, max_height))

    return warped_image


def cards_contours(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (7, 7), 0)
    t_lower = 50  # Lower Threshold
    t_upper = 150  # Upper threshold
    edge = cv2.Canny(blur, t_lower, t_upper)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
    dilated = cv2.dilate(edge, kernel)
    _, thresh = cv2.threshold(dilated, 100, 255, cv2.THRESH_OTSU)
    ctrs, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    areas = [cv2.contourArea(c) for c in ctrs]
    max_area = np.max(areas)
    correct_ctrs = []
    for c in ctrs:
        if 0.7 * max_area < cv2.contourArea(c) < 1.3 * max_area:
            correct_ctrs.append(c)
    return correct_ctrs


def return_shape_count(img, correct_ctrs):
    count = len(correct_ctrs)

    first_contour = correct_ctrs[0]

    
    approx = cv2.approxPolyDP(first_contour, 0.01 * cv2.arcLength(first_contour, True), True)

    convexHull = cv2.convexHull(first_contour, returnPoints = False)
    convexityDefects = cv2.convexityDefects(first_contour, convexHull)
    max_defect_length = np.max([d[0][3] for d in convexityDefects])

    if len(approx) == 4:
        shape = 'diamonds'
    elif max_defect_length > 2000:
        shape = 'squiggle'
    else:
        shape = 'oval'
#     print(f'{count} shape is: {shape}')
    return shape, count, first_contour


def return_color_shade(image, first_contour, shape):
    x,y,w,h = cv2.boundingRect(first_contour)
    rect_image = image[y:y+h, x:x+w]
    rect_image = rect_image.reshape((rect_image.shape[0] * rect_image.shape[1], 3))

    clt = sklearn.cluster.KMeans(n_clusters=2)
    labels = clt.fit_predict(rect_image)
    label_counts = Counter(labels)
    max_count = label_counts[0]
    density_ratio = list(label_counts.values())[0]/list(label_counts.values())[1]
#     print(density_ratio, label_counts)
    if shape == 'squiggle':  
        if density_ratio < 0.7:
            shade = 'full'
        elif density_ratio < 3.5:
            shade = 'striped'
        else:
            shade = 'empty'
    else:
        if density_ratio < 1.4:
            shade = 'full'
        elif density_ratio < 5.3:
            shade = 'striped'
        else:
            shade = 'empty'

    # reshape the image to be a list of pixels
    image = image.reshape((image.shape[0] * image.shape[1], 3))
    # cluster and assign labels to the pixels
    clt = sklearn.cluster.KMeans(n_clusters=2)
    labels = clt.fit_predict(image)
    
    
    # count labels to find most popular
    label_counts = Counter(labels)
    
    # subset out most popular centroid
    second_dominant = clt.cluster_centers_[label_counts.most_common(2)[1][0]]
#     print(second_dominant)
    color = bgr_to_color(second_dominant)
    return color, shade


def bgr_to_color(bgr):
    # unpack the RGB values into separate variables
    b,g,r = bgr

    # if the red value is greater than the green and blue values, return red
    if r > g and r > b and r > 150:
        return "red"

    # if the green value is greater than the red and blue values, return green
    elif g > r and g > b:
        return "green"

    # if none of the above conditions are met, return purple
    else:
        return "purple"


def label_card(warped_image):
    correct_contours = cards_contours(warped_image)
    shape, count, first_contour = return_shape_count(warped_image, correct_contours)
    color, shade = return_color_shade(warped_image, first_contour, shape)
    return shape,count,color,shade


def is_set(card1, card2, card3):
    # Check if the color is a set
    if (card1.color == card2.color and card2.color == card3.color) or \
       (card1.color != card2.color and card2.color != card3.color and card1.color != card3.color):
        # Check if the number of shapes is a set
        if (card1.count == card2.count and card2.count == card3.count) or \
           (card1.count != card2.count and card2.count != card3.count and card1.count != card3.count):
            # Check if the shade is a set
            if (card1.shade == card2.shade and card2.shade == card3.shade) or \
               (card1.shade != card2.shade and card2.shade != card3.shade and card1.shade != card3.shade):
                # Check if the shape is a set
                if (card1.shape == card2.shape and card2.shape == card3.shape) or \
                   (card1.shape != card2.shape and card2.shape != card3.shape and card1.shape != card3.shape):
                    return True
    return False


def return_all_sets(cards):
    combos = list(combinations(cards, 3))
    sets = []
    for combo in combos:
        if is_set(*combo):
            sets.append(list(combo))
    return sets


def multiple(sets):
    r = []
    seen = {}
    for s in sets:
        tup_set = []
        for card in s:
            if card in seen:
                tup_set.append((card, seen[card] + 1))
                seen[card] += 1
            else:
                tup_set.append((card, 0))
                seen[card] = 0
        r.append(tup_set)
    return r

colors = [
    (255, 0, 0),   # Red
    (0, 255, 0),   # Green
    (0, 0, 255),   # Blue
    (255, 255, 0), # Yellow
    (128, 0, 128), # Purple
    (0, 255, 255), # Cyan
    (255, 165, 0)  # Orange
]

def create_card(img, cntr, corner_point, bounding_rect):
    x,y,w,h = bounding_rect
    tl = (x,y)
    br = (x+w, y+h)
    warped_image = birds_eye_view(img, corner_point, bounding_rect[2], bounding_rect[3])
    shape,count,color,shade = label_card(warped_image)
    s = " ".join([shape,str(count),color,shade]) + ' '
    print(s)
    c = Card((tl, br), color, shape, count, shade)
    return c


def display_sets(path):
    cv2.namedWindow("x")
    img = cv2.imread(path)
    img = resize(img, 30)
    contours = pre_process(img)

    cntrs, corner_points, bounding_rects = relevant_contours(contours)

    cards = []

    with concurrent.futures.ThreadPoolExecutor() as executor:
        arg_list = list(zip(cntrs, corner_points, bounding_rects))
        cards = executor.map(create_card, [img] * len(cntrs), cntrs, corner_points, bounding_rects)

    sets = return_all_sets(cards)
#     print(sets)
    tup_sets = multiple(sets)

    for s in tup_sets:
        random_color = colors[random.randint(0, len(colors) - 1)]
        colors.remove(random_color)
        for tup in s:
            card = tup[0]
            m = tup[1]
            cv2.rectangle(img, tuple(map(lambda x: x - m * 10, card.tl_br[0])),
                                         tuple(map(lambda x: x + m * 10, card.tl_br[1])), random_color, 10)
    
#     cv2.imshow("x", img)

#     cv2.waitKey(0)

def video_display_sets(frame):
    contours = pre_process(frame)
    cntrs, corner_points, bounding_rects = relevant_contours(contours)

    cards = []
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        arg_list = list(zip(cntrs, corner_points, bounding_rects))
        cards = executor.map(create_card, [frame] * len(cntrs), cntrs, corner_points, bounding_rects)

    sets = return_all_sets(cards)
#     print(sets)
    tup_sets = multiple(sets)

    for s, color in zip(tup_sets, colors):
        random_color = colors[random.randint(0, len(colors) - 1)]
        colors.remove(random_color)
        for tup in s:
            card = tup[0]
            m = tup[1]
            cv2.rectangle(frame, tuple(map(lambda x: x - m * 10, card.tl_br[0])),
                                         tuple(map(lambda x: x + m * 10, card.tl_br[1])), color, 10)
    return frame

# %%
# %%time
display_sets('/Users/idotzhori/Desktop/set_detector/images/15.jpg')
# Out:
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# diamonds 3 green full
# diamonds 2 red full
# squiggle 2 purple full
# oval 3 red full
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# squiggle 2 red empty
# diamonds 3 green empty
# oval 2 purple empty
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# diamonds 1 green striped
# squiggle 2 green striped
# diamonds 3 green striped
# diamonds 1 green full
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/idotzhori/Desktop/set_detector/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# diamonds 3 purple striped
# diamonds 2 green empty
# squiggle 3 purple empty
# squiggle 1 red striped
# oval 2 purple striped
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[5], line 299, in display_sets(path)
#     296 tup_sets = multiple(sets)
#     298 for s in tup_sets:
# --> 299     random_color = colors[random.randint(0, len(colors) - 1)]
#     300     colors.remove(random_color)
#     301     for tup in s:
#
# File /opt/anaconda3/lib/python3.9/random.py:338, in Random.randint(self, a, b)
#     334 def randint(self, a, b):
#     335     """Return random integer in range [a, b], including both end points.
#     336     """
# --> 338     return self.randrange(a, b+1)
#
# File /opt/anaconda3/lib/python3.9/random.py:316, in Random.randrange(self, start, stop, step)
#     314     return istart + self._randbelow(width)
#     315 if step == 1:
# --> 316     raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#     318 # Non-unit step argument supplied.
#     319 istep = int(step)
#
# ValueError: empty range for randrange() (0, 0, 0)
